# %%
student = {
    "Name":"Ahmad Hassan",
    "Roll no":"SP24-BSE-023",
    "Age":22
}

# %%
type(student)
# Out:
# dict

# %%
import json

# %%
to_jason = json.dumps(student)

# %%
type(to_jason)
# Out:
# str

# %%
to_dict = json.loads(to_jason)

# %%
type(to_dict)
# Out:
# dict
